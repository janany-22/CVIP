# %% [markdown]
# # **IMPORTING THE LIBRARIES**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **READING THE DATASET**

# %%
data=pd.read_csv("/content/globalterrorismdb_0718dist.csv",encoding="ISO-8859-1")

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # **EXPLORATORY DATA ANALYSIS STARTS**

# %%
data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  1.970000e+11   1970       7     2        NaN         0        NaN       58
# 1  1.970000e+11   1970       0     0        NaN         0        NaN      130
# 2  1.970010e+11   1970       1     0        NaN         0        NaN      160
# 3  1.970010e+11   1970       1     0        NaN         0        NaN       78
# 4  1.970010e+11   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16204 entries, 0 to 16203
# Data columns (total 91 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   eventid           16204 non-null  float64
#  1   iyear             16204 non-null  int64
#  2   imonth            16204 non-null  int64
#  3   iday              16204 non-null  int64
#  4   approxdate        21 non-null     object
#  5   extended          16204 non-null  int64
#  6   resolution        338 non-null    object
#  7   country           16204 non-null  int64
#  8   country_txt       16204 non-null  object
#  9   region            16204 non-null  int64
#  10  region_txt        16204 non-null  object
#  11  provstate         16134 non-null  object
#  12  city              16204 non-null  object
#  13  latitude          15622 non-null  float64
#  14  longitude         15622 non-null  float64
#  15  specificity       16204 non-null  int64
# ...

# %%
data.describe()
# Out:
#             eventid         iyear        imonth          iday      extended  \
# count  1.620400e+04  16204.000000  16204.000000  16204.000000  16204.000000
# mean   1.977934e+11   1977.872192      6.210195     15.187423      0.020797
# std    3.245663e+08      3.248843      3.452949      8.957434      0.142710
# min    1.970000e+11   1970.000000      0.000000      0.000000      0.000000
# 25%    1.976080e+11   1976.000000      3.000000      7.000000      0.000000
# 50%    1.979040e+11   1979.000000      6.000000     15.000000      0.000000
# 75%    1.980100e+11   1980.000000      9.000000     23.000000      0.000000
# max    1.982050e+11   1986.000000     12.000000     31.000000      1.000000
#
#             country        region      latitude     longitude   specificity  \
# count  16204.000000  16204.000000  15622.000000  15622.000000  16204.000000
# mean     184.435325      5.544989     28.053607    -28.630864      1.248395
# ...

# %%
data.shape
# Out:
# (16204, 91)

# %%
data.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity', 'vicinity',
#        'location', 'summary', 'crit1', 'crit2', 'crit3', 'doubtterr',
#        'alternative', 'alternative_txt', 'multiple', 'success', 'suicide',
#        'attacktype1', 'attacktype1_txt', 'attacktype2', 'attacktype2_txt',
#        'Unnamed: 32', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2', 'gname',
#        'gsubname', 'gname2', 'Unnamed: 44', 'motive', 'guncertain1',
#        'individual', 'nperps', 'nperpcap', 'claimed', 'claimmode',
#        'claimmode_txt', 'weaptype1', 'weaptype1_txt', 'weapsubtype1',
#        'weapsubtype1_txt', 'weaptype2', 'weaptype2_txt', 'Unnamed: 59',
#        'weapdetail', 'nkill', 'nkillus', 'nkillter', 'nwound', 'nwoundus',
# ...

# %%
data.columns.nunique()
# Out:
# 91

# %% [markdown]
# # **CHECKING THE NULL VALUES**

# %%
data.isnull().sum()
# Out:
# eventid           0
# iyear             0
# imonth            0
# iday              0
# approxdate    16183
#               ...
# INT_LOG           1
# INT_IDEO          1
# INT_MISC          1
# INT_ANY           1
# related       15506
# Length: 91, dtype: int64

# %% [markdown]
# # **PICKING UP ONLY THE NECESSARY COLUMNS FOR ANALYSIS**

# %%
data=data[['eventid','iyear','imonth','iday','extended','country','country_txt','region','targsubtype1','attacktype1',
           'latitude','longitude','specificity','INT_IDEO','INT_MISC','INT_ANY']]

# %%
data.isna()
# Out:
#        eventid  iyear  imonth   iday  extended  country  country_txt  region  \
# 0        False  False   False  False     False    False        False   False
# 1        False  False   False  False     False    False        False   False
# 2        False  False   False  False     False    False        False   False
# 3        False  False   False  False     False    False        False   False
# 4        False  False   False  False     False    False        False   False
# ...        ...    ...     ...    ...       ...      ...          ...     ...
# 16199    False  False   False  False     False    False        False   False
# 16200    False  False   False  False     False    False        False   False
# 16201    False  False   False  False     False    False        False   False
# 16202    False  False   False  False     False    False        False   False
# 16203    False  False   False  False     False    False        False   False
#
# ...

# %%
data.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'extended', 'country',
#        'country_txt', 'region', 'targsubtype1', 'attacktype1', 'latitude',
#        'longitude', 'specificity', 'INT_IDEO', 'INT_MISC', 'INT_ANY'],
#       dtype='object')

# %% [markdown]
# # **RENAMING THE COLUMN NAMES AS OUR WISH IS DONE**

# %%
data=data.rename(columns={'iyear':'Year','imonth':'Month', 'iday':'Day','extended':'Extended','country':'Country','country_txt':'Country in text','region':'Region','targsubtype1':'Targsub',
                          'attacktype1':'Attacks','latitude':'Lat','longitude':'Lon','specificity':'Specific','INT_IDEO':'Intideo',
       'INT_MISC':'Intmisc', 'INT_ANY':'Intany'})

# %%
data.columns
# Out:
# Index(['eventid', 'Year', 'Month', 'Day', 'Extended', 'Country',
#        'Country in text', 'Region', 'Targsub', 'Attacks', 'Lat', 'Lon',
#        'Specific', 'Intideo', 'Intmisc', 'Intany'],
#       dtype='object')

# %%
data
# Out:
#             eventid  Year  Month  Day  Extended  Country     Country in text  \
# 0      1.970000e+11  1970      7    2         0       58  Dominican Republic
# 1      1.970000e+11  1970      0    0         0      130              Mexico
# 2      1.970010e+11  1970      1    0         0      160         Philippines
# 3      1.970010e+11  1970      1    0         0       78              Greece
# 4      1.970010e+11  1970      1    0         0      101               Japan
# ...             ...   ...    ...  ...       ...      ...                 ...
# 16199  1.982050e+11  1982      5   10         0      160         Philippines
# 16200  1.982050e+11  1982      5   10         0      160         Philippines
# 16201  1.982050e+11  1982      5   10         0      160         Philippines
# 16202  1.982050e+11  1982      5   10         0      160         Philippines
# 16203  1.982050e+11  1982      5   10         0      160         Philippines
#
# ...

# %% [markdown]
# # **FILLING UP THE NULL VALUES**

# %%
data['Intideo']=data['Intideo'].fillna('Unknown')

# %%
data['Intmisc']=data['Intmisc'].fillna('Unknown')

# %%
data['Intany']=data['Intany'].fillna('Unknown')

# %%
data['Lat']=data['Lat'].fillna('Unknown')

# %%
data['Lon']=data['Lon'].fillna('Unknown')

# %%
data['Targsub']=data['Targsub'].fillna('Unknown')

# %%
data.isnull().sum()
# Out:
# eventid            0
# Year               0
# Month              0
# Day                0
# Extended           0
# Country            0
# Country in text    0
# Region             0
# Targsub            0
# Attacks            0
# Lat                0
# Lon                0
# Specific           0
# Intideo            0
# Intmisc            0
# Intany             0
# dtype: int64

# %% [markdown]
# # **VISUALIZATION USING PLOTTING**

# %%
plt.figure(figsize=(20,20))
heading=['Attacks In Day','Attacks In Month']
columns=['Day','Month']
for i,col in enumerate(columns):
  plt.subplot(2,1,i+1)
  plt.title(heading[i])
  sns.kdeplot(x=data[col])
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20,20))
heading=['Attacks In Day','Attacks In Month']
columns=['Day','Month']
for i,col in enumerate(columns):
  plt.subplot(2,1,i+1)
  plt.title(heading[i])
  sns.stripplot(x=data[col])
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20,20))
heading=['Attacks In Day','Attacks In Month']
columns=['Day','Month']
for i,col in enumerate(columns):
  plt.subplot(2,1,i+1)
  plt.title(heading[i],fontsize=20)
  plt.xlabel(col,fontsize=20)
  sns.swarmplot(x=data[col])
plt.tight_layout()
plt.show()

# %% [markdown]
# # **ATTACKS IN THE REGIONS AND COUNTRY**

# %%
plt.figure(figsize=(20,20))
heading=['Attacks In Region','Attacks In Country']
columns=['Region','Country']
for i,col in enumerate(columns):
  plt.subplot(2,1,i+1)
  plt.title(heading[i],fontsize=20)
  plt.xticks(rotation=360)
  plt.xlabel(col,fontsize=20)
  sns.countplot(x=data[col])
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20,20))
heading=['Attacks In Region','Attacks In Country']
columns=['Region','Country in text']
for i,col in enumerate(columns):
  plt.subplot(2,1,i+1)
  plt.title(heading[i],fontsize=20)
  plt.xticks(rotation=90)
  plt.xlabel(col,fontsize=20)
  sns.countplot(x=data[col])
plt.tight_layout()
plt.show()

# %% [markdown]
# # **VINOLIN PLOT FOR ATTACKS**

# %%
plt.figure(figsize=(10,10))
plt.xticks(rotation=60)
plt.yticks(rotation=60)
plt.title('Attacks')
sns.violinplot(x=data['Attacks'],y=data['Day'])
# Out:
# <Axes: title={'center': 'Attacks'}, xlabel='Attacks', ylabel='Day'>

# %% [markdown]
# # **ATTACKS IN EACH REGION BASED ON THE YEAR**

# %%
pd.crosstab(data.Year,data.Region).plot(kind='area',figsize=(15,8))
plt.title("ATTACKS IN EACH REGION")
plt.xlabel('Year')
plt.ylabel('Attacks')
plt.show()
